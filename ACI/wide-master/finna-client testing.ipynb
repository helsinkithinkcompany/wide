# %%
from finna_client import FinnaClient as fc
from finna_client import FinnaSearchType as fst 
import time 

tst1 = fc() 
lookfor = "EEG"

# %%
time1 = time.time() 
tst1_res = tst1.search(lookfor=lookfor,
                       search_type=fst.Subject,
                       fields=["buildings", "subjects"],
                       filters=["main_date_str:2017"],
                       page=1,
                       limit=100)
time2 = time.time() 
print("Time it took: {:6.4f}s".format(time2-time1))
# Out:
# Time it took: 0.1952s

# %%
def count_subjects(records):
    subject_count = {} 
    for record in records: 
        for subject in record['subjects']:
            subject = subject[0].lower() 
            try: 
                subject_count [subject] += 1 
            except KeyError: 
                subject_count [subject] = 1
    return subject_count
            
count_subjects(tst1_res['records'])
# Out:
# {'mietiskely': 1,
#  'tietoinen läsnäolo': 1,
#  'eeg': 18,
#  'sanat': 1,
#  'prosessointi': 1,
#  'merkitys': 1,
#  'organisaatiot': 1,
#  'herätevaste': 1,
#  'elektromyografia': 1,
#  'korrelaatio': 1,
#  'silmänliikkeet': 1,
#  'neuroverkot': 1,
#  'emd': 1,
#  'huippukorrelaatioanalyysi': 1,
#  'responses': 1,
#  'emotions': 1,
#  'neurons': 1,
#  'spectral linear discriminant analysis': 1,
#  'brain': 2,
#  'syke': 1,
#  'heart rate variability': 1,
#  'hrv': 1,
#  'cardiac cycle': 1,
#  'learning': 1,
#  'trace conditioning': 1,
#  'electroencephalography.': 2,
#  'magnetoencephalography.': 2,
#  'short-term memory.': 2,
#  'fysiologia ja neurotiede': 2,
#  'hermoverkko': 2,
#  'meg': 3,
#  'työmuisti': 2,
#  'masennus': 3,
#  'kasvontunnistus': 1,
#  'ilmeet': 3,
#  'tunteet': 1,
#  'tulkinta': 1,
#  'aivotutkimus': 3,
#  'neuropsykologia': 3,
#  'psykoterapia': 1,
#  'kognitiivinen terapia': 1,
#  'käyttäytymisterapia': 1,
#  'ryhmäterapia': 1,
#  'cbasp': 1,
#  'eye diseases': 1,
#  'facial expressions': 1,
#  'visuality': 1,
#  'recognition': 1,
#  'facial recognition': 1,
#  'age-related eye diseases': 1,
#  'bevacizumab': 1,
#  'face recognition': 1,
#  'n170': 1,
#  'ms-tauti': 2,
#  'potilaat': 2,
#  'kognitio': 2,
#  'kognitiiviset prosessit': 2,
#  'arviointi': 2,
#  'elämänlaatu': 2,
#  'heikentyminen': 2,
#  'uupumus': 2,
#  'neurofysiologia': 2,
#  'mittaus': 2,
#  'cnv': 2,
#  'p3': 2,
#  'cognition': 2,
#  'fatigue': 2,
#  'multiple sclerosis': 2,
#  'quality of life': 2,
#  'ikääntyneet': 1,
#  'kuvantaminen': 2,
#  'magneettitutkimus': 4,
#  'magnetoencephalography': 1,
#  'electroencephalography': 1,
#  'brain mapping': 1,
#  'brain diseases': 1,
#  'epilepsia': 2,
#  'hermoston taudit': 1,
#  'diagnostiikka': 2,
#  'oireet': 1,
#  'vilppula, anitta.': 1,
#  'röntgentutkimus': 1,
#  'ultraäänitutkimus': 1,
#  'tietokonetomografia': 1,
#  'liitännäistaudit': 1,
#  'uni': 1,
#  'hengitys': 1,
#  'häiriöt': 1,
#  'esiintyvyys': 1,
#  'tutkimus': 1,
#  'kyselytutkimus': 1,
#  'univaje': 1,
#  'väsymys': 1,
#  'uniapnea-oireyhtymä': 1,
#  'unihäiriöt': 1,
#  'äkkikuolema': 1,
#  'kuolleisuus': 1,
#  'hoitomenetelmät': 1,
#  'lääkehoito': 1,
#  'suomi': 1,
#  'unipolygrafia': 1,
#  'obstruktiivinen uniapnea': 1,
#  'cpap': 1,
#  'temporaaliepilepsia': 1,
#  'otsolohkoepilepsia': 1,
#  'robotit': 1,
#  'tekoäly': 1,
#  'uhkakuvat': 1,
#  'autonomiset järjestelmät': 1,
#  'keksinnöt': 1,
#  'innovaatiot': 1,
#  'ihminen-konejärjestelmät': 1,
#  'algoritmit': 1,
#  'robotiikka': 1,
#  'hakkerointi': 1,
#  'ihminen': 1,
#  'sotatekniikka': 1,
#  'manipulaatio': 1,
#  'telepatia': 1,
#  'kauko-ohjaus': 1,
#  'koneet': 1,
#  'muisti': 1,
#  'tietoturva': 1,
#  'teknologia': 1,
#  'ajatukset': 1}

# %%
tst1_res['records'][0]['buildings'][0]['translated']
# Out:
# 'Jyväskylän yliopisto'

# %%
a = { 'a': 1, 'b': 2}

try:
    a['c'] += 1 
except KeyError: 
    a['c'] = 1

a
# Out:
# {'a': 1, 'b': 2, 'c': 1}

# %%
'Short-term memory.'.lower()
# Out:
# 'short-term memory.'

# %%
result['records'][0]['subjects']
# Out:
# ['mietiskely', 'tietoinen läsnäolo', 'EEG']

# %%
fc().search(lookfor="cadilac",
                   search_type=fst.Subject,
                   fields=["buildings", "subjects"],
                   filters=["main_date_str:2017"],
                   page=1,
                   limit=100)
# Out:
# {'resultCount': 0, 'status': 'OK'}

# %%
def get_and_beautify_data_from_api(lookfor = "EEG", year = "2017") : 
    result = fc().search(lookfor=lookfor,
                           search_type=fst.Subject,
                           fields=["buildings", "subjects"],
                           filters=["main_date_str:{year}".format(year = year)],
                           page=1,
                           limit=100)
    b_result = {}
    b_result['resultCount'] = result['resultCount']
    if result['resultCount'] != 0: 
        tmp_records = []
        for record in result['records']:
            tmp_record = {}
            tmp_record['building'] = record['buildings'][0]['translated']
            tmp_record['subjects'] = [subject[0] for subject in record['subjects']]
            tmp_records.append(tmp_record)
        b_result['records'] = tmp_records
    else: 
        b_result['records'] =[0]
    return b_result

result = get_and_beautify_data_from_api()

# %%
def count_orgs(records):
    orgs_count = {} 
    for record in records:
        try : 
            orgs_count[record['building']] += 1 
        except KeyError:
            orgs_count[record['building']]  = 1
    return orgs_count

orgs_count = count_orgs(result['records'])

# %%
def count_subjects(records):
    subject_count = {} 
    for record in records: 
        for subject in record['subjects']:
            subject = subject.lower() 
            try: 
                subject_count [subject] += 1 
            except KeyError: 
                subject_count [subject] = 1
    return subject_count
            
subjects_count = count_subjects(result['records'])

# %%
subjects_count.keys()
# Out:
# dict_keys(['mietiskely', 'tietoinen läsnäolo', 'eeg', 'sanat', 'prosessointi', 'merkitys', 'organisaatiot', 'herätevaste', 'elektromyografia', 'korrelaatio', 'silmänliikkeet', 'neuroverkot', 'emd', 'huippukorrelaatioanalyysi', 'responses', 'emotions', 'neurons', 'spectral linear discriminant analysis', 'brain', 'syke', 'heart rate variability', 'hrv', 'cardiac cycle', 'learning', 'trace conditioning', 'electroencephalography.', 'magnetoencephalography.', 'short-term memory.', 'fysiologia ja neurotiede', 'hermoverkko', 'meg', 'työmuisti', 'masennus', 'kasvontunnistus', 'ilmeet', 'tunteet', 'tulkinta', 'aivotutkimus', 'neuropsykologia', 'psykoterapia', 'kognitiivinen terapia', 'käyttäytymisterapia', 'ryhmäterapia', 'cbasp', 'eye diseases', 'facial expressions', 'visuality', 'recognition', 'facial recognition', 'age-related eye diseases', 'bevacizumab', 'face recognition', 'n170', 'ms-tauti', 'potilaat', 'kognitio', 'kognitiiviset prosessit', 'arviointi', 'elämänlaatu', 'heikentyminen', 'uupumus', 'neurofysiologia', 'mittaus', 'cnv', 'p3', 'cognition', 'fatigue', 'multiple sclerosis', 'quality of life', 'ikääntyneet', 'kuvantaminen', 'magneettitutkimus', 'magnetoencephalography', 'electroencephalography', 'brain mapping', 'brain diseases', 'epilepsia', 'hermoston taudit', 'diagnostiikka', 'oireet', 'vilppula, anitta.', 'röntgentutkimus', 'ultraäänitutkimus', 'tietokonetomografia', 'liitännäistaudit', 'uni', 'hengitys', 'häiriöt', 'esiintyvyys', 'tutkimus', 'kyselytutkimus', 'univaje', 'väsymys', 'uniapnea-oireyhtymä', 'unihäiriöt', 'äkkikuolema', 'kuolleisuus', 'hoitomenetelmät', 'lääkehoito', 'suomi', 'unipolygrafia', 'obstruktiivinen uniapnea', 'cpap', 'temporaaliepilepsia', 'otsolohkoepilepsia', 'robotit', 'tekoäly', 'uhkakuvat', 'autonomiset järjestelmät', 'keksinnöt', 'innovaatiot', 'ihminen-konejärjestelmät', 'algoritmit', 'robotiikka', 'hakkerointi', 'ihminen', 'sotatekniikka', 'manipulaatio', 'telepatia', 'kauko-ohjaus', 'koneet', 'muisti', 'tietoturva', 'teknologia', 'ajatukset'])

# %%
len(subjects_count)
# Out:
# 125

# %%
{}.fromkeys(subjects_count.keys())
# Out:
# {'mietiskely': None,
#  'tietoinen läsnäolo': None,
#  'eeg': None,
#  'sanat': None,
#  'prosessointi': None,
#  'merkitys': None,
#  'organisaatiot': None,
#  'herätevaste': None,
#  'elektromyografia': None,
#  'korrelaatio': None,
#  'silmänliikkeet': None,
#  'neuroverkot': None,
#  'emd': None,
#  'huippukorrelaatioanalyysi': None,
#  'responses': None,
#  'emotions': None,
#  'neurons': None,
#  'spectral linear discriminant analysis': None,
#  'brain': None,
#  'syke': None,
#  'heart rate variability': None,
#  'hrv': None,
#  'cardiac cycle': None,
#  'learning': None,
#  'trace conditioning': None,
#  'electroencephalography.': None,
#  'magnetoencephalography.': None,
#  'short-term memory.': None,
#  'fysiologia ja neurotiede': None,
#  'hermoverkko': None,
#  'meg': None,
#  'työmuisti': None,
#  'masennus': None,
#  'kasvontunnistus': None,
#  'ilmeet': None,
#  'tunteet': None,
#  'tulkinta': None,
#  'aivotutkimus': None,
#  'neuropsykologia': None,
#  'psykoterapia': None,
#  'kognitiivinen terapia': None,
#  'käyttäytymisterapia': None,
#  'ryhmäterapia': None,
#  'cbasp': None,
#  'eye diseases': None,
#  'facial expressions': None,
#  'visuality': None,
#  'recognition': None,
#  'facial recognition': None,
#  'age-related eye diseases': None,
#  'bevacizumab': None,
#  'face recognition': None,
#  'n170': None,
#  'ms-tauti': None,
#  'potilaat': None,
#  'kognitio': None,
#  'kognitiiviset prosessit': None,
#  'arviointi': None,
#  'elämänlaatu': None,
#  'heikentyminen': None,
#  'uupumus': None,
#  'neurofysiologia': None,
#  'mittaus': None,
#  'cnv': None,
#  'p3': None,
#  'cognition': None,
#  'fatigue': None,
#  'multiple sclerosis': None,
#  'quality of life': None,
#  'ikääntyneet': None,
#  'kuvantaminen': None,
#  'magneettitutkimus': None,
#  'magnetoencephalography': None,
#  'electroencephalography': None,
#  'brain mapping': None,
#  'brain diseases': None,
#  'epilepsia': None,
#  'hermoston taudit': None,
#  'diagnostiikka': None,
#  'oireet': None,
#  'vilppula, anitta.': None,
#  'röntgentutkimus': None,
#  'ultraäänitutkimus': None,
#  'tietokonetomografia': None,
#  'liitännäistaudit': None,
#  'uni': None,
#  'hengitys': None,
#  'häiriöt': None,
#  'esiintyvyys': None,
#  'tutkimus': None,
#  'kyselytutkimus': None,
#  'univaje': None,
#  'väsymys': None,
#  'uniapnea-oireyhtymä': None,
#  'unihäiriöt': None,
#  'äkkikuolema': None,
#  'kuolleisuus': None,
#  'hoitomenetelmät': None,
#  'lääkehoito': None,
#  'suomi': None,
#  'unipolygrafia': None,
#  'obstruktiivinen uniapnea': None,
#  'cpap': None,
#  'temporaaliepilepsia': None,
#  'otsolohkoepilepsia': None,
#  'robotit': None,
#  'tekoäly': None,
#  'uhkakuvat': None,
#  'autonomiset järjestelmät': None,
#  'keksinnöt': None,
#  'innovaatiot': None,
#  'ihminen-konejärjestelmät': None,
#  'algoritmit': None,
#  'robotiikka': None,
#  'hakkerointi': None,
#  'ihminen': None,
#  'sotatekniikka': None,
#  'manipulaatio': None,
#  'telepatia': None,
#  'kauko-ohjaus': None,
#  'koneet': None,
#  'muisti': None,
#  'tietoturva': None,
#  'teknologia': None,
#  'ajatukset': None}

# %%
{key: {key:0 for key in subjects_count.keys()} for key in subjects_count.keys() }
# Out:
# {'mietiskely': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'tietoinen läsnäolo': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'eeg': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'sanat': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'prosessointi': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'merkitys': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'organisaatiot': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'herätevaste': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'elektromyografia': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'korrelaatio': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'silmänliikkeet': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'neuroverkot': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'emd': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'huippukorrelaatioanalyysi': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'responses': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'emotions': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'neurons': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'spectral linear discriminant analysis': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'brain': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
# ...
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'kauko-ohjaus': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'koneet': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'muisti': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'tietoturva': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'teknologia': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0},
#  'ajatukset': {'mietiskely': 0,
#   'tietoinen läsnäolo': 0,
#   'eeg': 0,
#   'sanat': 0,
#   'prosessointi': 0,
#   'merkitys': 0,
#   'organisaatiot': 0,
#   'herätevaste': 0,
#   'elektromyografia': 0,
#   'korrelaatio': 0,
#   'silmänliikkeet': 0,
#   'neuroverkot': 0,
#   'emd': 0,
#   'huippukorrelaatioanalyysi': 0,
#   'responses': 0,
#   'emotions': 0,
#   'neurons': 0,
#   'spectral linear discriminant analysis': 0,
#   'brain': 0,
#   'syke': 0,
#   'heart rate variability': 0,
#   'hrv': 0,
#   'cardiac cycle': 0,
#   'learning': 0,
#   'trace conditioning': 0,
#   'electroencephalography.': 0,
#   'magnetoencephalography.': 0,
#   'short-term memory.': 0,
#   'fysiologia ja neurotiede': 0,
#   'hermoverkko': 0,
#   'meg': 0,
#   'työmuisti': 0,
#   'masennus': 0,
#   'kasvontunnistus': 0,
#   'ilmeet': 0,
#   'tunteet': 0,
#   'tulkinta': 0,
#   'aivotutkimus': 0,
#   'neuropsykologia': 0,
#   'psykoterapia': 0,
#   'kognitiivinen terapia': 0,
#   'käyttäytymisterapia': 0,
#   'ryhmäterapia': 0,
#   'cbasp': 0,
#   'eye diseases': 0,
#   'facial expressions': 0,
#   'visuality': 0,
#   'recognition': 0,
#   'facial recognition': 0,
#   'age-related eye diseases': 0,
#   'bevacizumab': 0,
#   'face recognition': 0,
#   'n170': 0,
#   'ms-tauti': 0,
#   'potilaat': 0,
#   'kognitio': 0,
#   'kognitiiviset prosessit': 0,
#   'arviointi': 0,
#   'elämänlaatu': 0,
#   'heikentyminen': 0,
#   'uupumus': 0,
#   'neurofysiologia': 0,
#   'mittaus': 0,
#   'cnv': 0,
#   'p3': 0,
#   'cognition': 0,
#   'fatigue': 0,
#   'multiple sclerosis': 0,
#   'quality of life': 0,
#   'ikääntyneet': 0,
#   'kuvantaminen': 0,
#   'magneettitutkimus': 0,
#   'magnetoencephalography': 0,
#   'electroencephalography': 0,
#   'brain mapping': 0,
#   'brain diseases': 0,
#   'epilepsia': 0,
#   'hermoston taudit': 0,
#   'diagnostiikka': 0,
#   'oireet': 0,
#   'vilppula, anitta.': 0,
#   'röntgentutkimus': 0,
#   'ultraäänitutkimus': 0,
#   'tietokonetomografia': 0,
#   'liitännäistaudit': 0,
#   'uni': 0,
#   'hengitys': 0,
#   'häiriöt': 0,
#   'esiintyvyys': 0,
#   'tutkimus': 0,
#   'kyselytutkimus': 0,
#   'univaje': 0,
#   'väsymys': 0,
#   'uniapnea-oireyhtymä': 0,
#   'unihäiriöt': 0,
#   'äkkikuolema': 0,
#   'kuolleisuus': 0,
#   'hoitomenetelmät': 0,
#   'lääkehoito': 0,
#   'suomi': 0,
#   'unipolygrafia': 0,
#   'obstruktiivinen uniapnea': 0,
#   'cpap': 0,
#   'temporaaliepilepsia': 0,
#   'otsolohkoepilepsia': 0,
#   'robotit': 0,
#   'tekoäly': 0,
#   'uhkakuvat': 0,
#   'autonomiset järjestelmät': 0,
#   'keksinnöt': 0,
#   'innovaatiot': 0,
#   'ihminen-konejärjestelmät': 0,
#   'algoritmit': 0,
#   'robotiikka': 0,
#   'hakkerointi': 0,
#   'ihminen': 0,
#   'sotatekniikka': 0,
#   'manipulaatio': 0,
#   'telepatia': 0,
#   'kauko-ohjaus': 0,
#   'koneet': 0,
#   'muisti': 0,
#   'tietoturva': 0,
#   'teknologia': 0,
#   'ajatukset': 0}}

# %%
#Return cooccurence matrix with keys (dict type)
def count_subjects_presented_together_one_publishcation(records, subjects_count):
    subjects_presented_together_count = {key: {key:0 for key in subjects_count.keys()} for key in subjects_count.keys() }
    for record in records:
        for subject in record['subjects']:
            for subject_ in record['subjects']:
                subjects_presented_together_count[subject.lower()][subject_.lower()] += 1
            
    return subjects_presented_together_count 

cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)

# %%
#Return a matrix len(subjects_count) x len(subjects_count)
def cooccurence_matrix(cooccurence_with_keys):
    cooc_matrix = []
    for y in cooccurence_with_keys: 
        x_tmp = [] 
        for x in cooccurence_with_keys[y]: 
            x_tmp.append(cooccurence_with_keys[y][x])
        cooc_matrix.append(x_tmp)
    return cooc_matrix

cooc_matrix = cooccurence_matrix(cooccurence_with_keys)

# %%
def subject_scoring(cooc_matrix):
    subject_scores = [ ]
    for subject in cooc_matrix:
        subject_scores.append(sum(subject))
    return subject_scores

subject_scores = subject_scoring(cooc_matrix)

# %%
subject_scores_full = dict(zip(subjects_count.keys() , subject_scores))
[[k, subject_scores_full[k]] for k in sorted(subject_scores_full, key=subject_scores_full.get, reverse=True)][:50]
# Out:
# [['vietnam', 543],
#  ['united states.', 326],
#  ['vietnamin sota', 184],
#  ['vietnam war, 1961-1975', 159],
#  ['vallankumoukset', 126],
#  ['ruokakulttuuri', 114],
#  ['yhdysvallat', 113],
#  ['kaupungit', 97],
#  ['armed forces', 90],
#  ['kehitysmaat', 88],
#  ['hmong (asian people)', 84],
#  ['ethnology', 83],
#  ['kehitysyhteistyö', 79],
#  ['sodat', 78],
#  ['kiina', 77],
#  ['menetys', 73],
#  ['jälleenrakentaminen', 70],
#  ['matkat', 70],
#  ['vietnam war (1961-1975)', 69],
#  ['kehittyneet maat', 65],
#  ['kenia', 65],
#  ['aasia', 64],
#  ['fors, malin,', 63],
#  ['murha', 63],
#  ['popular music', 62],
#  ['social science', 61],
#  ['suomi', 60],
#  ['leadership.', 60],
#  ['military chaplains.', 60],
#  ['submariners.', 60],
#  ['laos', 60],
#  ['poliisikirjallisuus', 58],
#  ['rikoskirjallisuus', 58],
#  ['jännityskirjallisuus', 58],
#  ['katoaminen', 58],
#  ['perinnöt', 58],
#  ['adoptio', 58],
#  ['ihmisryöstöt', 58],
#  ['ottolapset', 58],
#  ['poliisit', 58],
#  ['borderlands', 56],
#  ['china', 56],
#  ['brasilia', 52],
#  ['food supply', 50],
#  ['intia', 50],
#  ['youth', 48],
#  ['nigeria', 48],
#  ['history', 47],
#  ['chile', 46],
#  ['kaakkois-aasia', 45]]

# %%
[[k, orgs_count[k]] for k in sorted(orgs_count, key=orgs_count.get, reverse=True)][:10]
# Out:
# [['Kansalliskirjasto', 17],
#  ['Helmet-kirjastot', 14],
#  ['Helka-kirjastot', 12],
#  ['Jyväskylän yliopisto', 9],
#  ['Maanpuolustuskorkeakoulu', 7],
#  ['Lahden ammattikorkeakoulu', 6],
#  ['Eepos-kirjastot', 5],
#  ['Eduskunnan kirjasto', 4],
#  ['Savonia-ammattikorkeakoulu', 3],
#  ['Lastu-kirjastot', 3]]

# %%
result = get_and_beautify_data_from_api(lookfor="lidar", year="2015")
orgs_count = count_orgs(result['records'])#for bubble chart 
subjects_count = count_subjects(result['records'])
cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart
print("Organizations: {}\nRelated subjects: {}".format(orgs_count, list(subjects_count.keys())))
# Out:
# Organizations: {'Kansalliskirjasto': 1, 'Itä-Suomen yliopisto': 1}
# Related subjects: ['metsäpinta-ala', 'trooppiset metsät', 'forests', 'area', 'canopy', 'cartography', 'vegetation index', 'satellite imagery', 'lidar', 'regression analysis', 'mathematical models', 'forest mensuration', 'international forest definition', 'alos avnir-2', 'beta regression', 'logistic regression', 'estimation', 'technology & engineering / remote sensing & geographic information systems.', 'remote sensing.', 'tutkimussatelliitit', 'lämpökuvaus', 'spektroskopia', 'kaukokartoitus', 'kartoitus', 'ilmakuvat', 'kuvankäsittely', 'ilmakuvaus', 'fotogrammetria', 'satelliittikuvaus', 'earth resources technology satellites.', 'spot (artificial satellite).', 'photogrammetry', 'image analysis.', 'landsat satellites.', 'monispektrinen kaukokartoitus', 'hyperspektrinen kaukokartoitus']

# %%
result = get_and_beautify_data_from_api(lookfor="SICK", year="2010")
orgs_count = count_orgs(result['records'])#for bubble chart 
subjects_count = count_subjects(result['records'])
cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart

subject_scores        = subject_scoring(cooc_matrix)
subject_scores_full   = dict(zip(subjects_count.keys() , subject_scores))
top_50_subjects       = [[k, subject_scores_full[k]] for k in sorted(subject_scores_full, key=subject_scores_full.get, reverse=True)][:50]
top_10_orgs           = [[k, orgs_count[k]] for k in sorted(orgs_count, key=orgs_count.get, reverse=True)][:10]

print("Organizations: {}\nRelated subjects: {}".format(top_10_orgs, top_50_subjects))
# Out:
# Organizations: [['Helka-kirjastot', 10], ['Centria-kirjasto', 3], ['Jyväskylän yliopisto', 2], ['Åbo Akademis bibliotek', 1], ['Aalto-yliopisto', 1], ['Tritonia', 1], ['Varastokirjasto', 1], ['Kansalliskirjasto', 1]]
# Related subjects: [['musculoskeletal diseases', 160], ['pain', 156], ['sick leave', 150], ['occupational health', 112], ['work', 112], ['workload', 112], ['medical', 100], ['health status', 91], ['aids (disease)', 80], ['family relations', 73], ['job satisfaction', 73], ['personal satisfaction', 73], ['stress, psychological', 73], ['työkyky', 65], ['toimintakyky', 60], ['back pain', 55], ['occupational diseases', 55], ['työpaikat', 54], ['adult', 52], ['aging', 52], ['employment', 52], ['middle aged', 52], ['socioeconomic factors', 52], ['esiintyvyys', 52], ['kipu', 52], ['kunnan työntekijät', 52], ['psykososiaaliset tekijät', 52], ['riskiryhmät', 52], ['riskitekijät', 52], ['helsinki', 52], ['työhyvinvointi', 52], ['sairausloma', 45], ['luottamus', 43], ['sick', 40], ['treatment outcome', 39], ['efficiency', 39], ['human engineering', 39], ['lifting', 39], ['patient education as topic', 39], ['upper extremity', 39], ['work capacity evaluation', 39], ['sick.', 38], ['insurance, disability', 32], ['religion', 32], ['church work with the sick.', 32], ['reaktor innovations (yhtiö)', 31], ['sick (yhtiö)', 31], ['accenture (yhtiö)', 31], ['työviihtyvyys', 31], ['työtyytyväisyys', 31]]

# %%
result = get_and_beautify_data_from_api(lookfor="finnish", year="2015")
orgs_count = count_orgs(result['records'])#for bubble chart 
subjects_count = count_subjects(result['records'])
cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart

subject_scores        = subject_scoring(cooc_matrix)
subject_scores_full   = dict(zip(subjects_count.keys() , subject_scores))
top_50_subjects       = [[k, subject_scores_full[k]] for k in sorted(subject_scores_full, key=subject_scores_full.get, reverse=True)][:50]
top_10_orgs           = [[k, orgs_count[k]] for k in sorted(orgs_count, key=orgs_count.get, reverse=True)][:10]

print("Organizations: {}\nRelated subjects: {}".format(top_10_orgs, top_50_subjects))
# Out:
# Organizations: [['Kansalliskirjasto', 40], ['Oulun yliopisto', 22], ['Jyväskylän yliopisto', 17], ['Helka-kirjastot', 9], ['Itä-Suomen yliopisto', 3], ['Svenska handelshögskolan', 2], ['Aalto-yliopisto', 2], ['Arcadan kirjasto', 1], ['Suomalaisen Kirjallisuuden Seura', 1], ['Eduskunnan kirjasto', 1]]
# Related subjects: [['suomen kieli', 298], ['kielenhuolto', 91], ['oppikirjat', 84], ['aikuiset', 81], ['kansanlingvistiikka', 80], ['suomi', 76], ['kielitaito', 76], ['asenteet', 70], ['paikallislehdet', 70], ['sanomalehdet', 70], ['toimittajat', 70], ['vuxna', 61], ['finnish as a second language', 60], ['cefr', 60], ['kielioppaat', 59], ['diskurssit', 58], ['kriittinen diskurssianalyysi', 58], ['språkkunskap', 56], ['oikeakielisyys', 55], ['suomi toisena kielenä', 55], ['tekstintutkimus', 55], ['kielenkäyttö', 55], ['dialogisuus', 55], ['kognitiivinen kielitiede', 55], ['konstruktiokielioppi', 55], ['kielen omaksuminen', 55], ['kirjoitustaito', 55], ['semantiikka', 55], ['nuoret', 55], ['korpustutkimus', 55], ['construction', 55], ['socio-cognitive approach', 55], ['usage-based learning', 55], ['adult and young learners', 55], ['local cases', 55], ['poland', 54], ['finska', 53], ['yleisradio.', 48], ['diskurssi', 48], ['kielivirheet', 48], ['palaute', 48], ['radiotoimittajat', 48], ['finnish language', 46], ['kielioppi', 39], ['bayesian networks.', 38], ['cost-benefit analysis.', 38], ['decision support.', 38], ['dispersants.', 38], ['environmental valuation.', 38], ['finnish archipelago sea.', 38]]

# %%
result = get_and_beautify_data_from_api(lookfor="cadilac", year="2015")
if result['records'][0] != 0:
    orgs_count = count_orgs(result['records'])#for bubble chart 
    subjects_count = count_subjects(result['records'])
    cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
    cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart

    subject_scores        = subject_scoring(cooc_matrix)
    subject_scores_full   = dict(zip(subjects_count.keys() , subject_scores))
    top_50_subjects       = [[k, subject_scores_full[k]] for k in sorted(subject_scores_full, key=subject_scores_full.get, reverse=True)][:50]
    top_10_orgs           = [[k, orgs_count[k]] for k in sorted(orgs_count, key=orgs_count.get, reverse=True)][:10]

    print("Organizations: {}\nRelated subjects: {}".format(top_10_orgs, top_50_subjects))
else: 
    print("No result!!!!!")
# Out:
# No result!!!!!

# %%
get_and_beautify_data_from_api(lookfor="cadilac", year="2015")
# Out:
# {'resultCount': 0, 'records': [0]}

# %%
result = get_and_beautify_data_from_api(lookfor="gene", year="2015")
if result['records'][0] != 0:
    orgs_count = count_orgs(result['records'])#for bubble chart 
    subjects_count = count_subjects(result['records'])
    cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
    cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart
    print("Organizations: {}\nRelated subjects: {}".format(orgs_count, list(subjects_count.keys())))
else: 
    print("No result!!!!!")
# Out:
# Organizations: {'Jyväskylän yliopisto': 19, 'Helka-kirjastot': 49, 'Itä-Suomen yliopisto': 21, 'Kansalliskirjasto': 3, 'Tampereen yliopisto': 1, 'Aalto-yliopisto': 1, 'Turun yliopisto': 2, 'Metropolian kirjaston kokoelmat': 1, 'Oulun yliopisto': 2, 'Eepos-kirjastot': 1}
# Related subjects: ['ecological genetics', 'gene expression', 'transcription', 'evoluutioekologia', 'fenotyyppi', 'geenit', 'hyönteiset', 'kuningattaret', 'muurahaiset', 'plastisuus', 'säätely', 'työläiset', 'caste', 'ekspressioverkostot', 'evolutiivinen innovaatio', 'formica', 'gene duplication', 'kastit', 'life stages', 'protein modeling', 'rna sequencing', 'social insects', 'transcriptomics', 'vitellogenin', 'hajuhaitat', 'havainnointi', 'korrelaatio', 'maksamyrkyt', 'maku', 'menetelmät', 'mikrobiologia', 'molekyylibiologia', 'hermomyrkyt', 'syanobakteerit', 'gardajärvi', 'itämeri', '2-metyyli-isoborneoli', 'anabaena sp. strain 37', 'anatoxin-a synthetase gene cluster', 'beta-ionone', 'cyanobacteria', 'geosmiini', 'geosmin synthase', 'luonnonvedet', 'mib synthase gene', 'nor-carotenoid', 'off-flavor', 'sekundaarimetabolia', 'physical activity', 'genes', 'mortality', 'adults', 'origin of viruses', 'virus capsids', 'capsid genes', 'antibiootit', 'eläinlääketiede', 'ihmiset', 'jätevedenpuhdistamot', 'jäämät', 'kalanviljely', 'mikro-organismit', 'resistenssi', 'sedimentit', 'antibiotic resistance', 'biogeography', 'horizontal gene transfer', 'algorithms.', 'antineoplastic agents', 'computational biology.', 'computer simulation.', 'dna methylation.', 'gene dosage', 'gene expression profiling', 'gene expression regulation, neoplastic', 'genomic instability.', 'individualized medicine.', 'neoplasms', 'pharmacogenetics.', 'software.', 'statistics as topic.', 'systems integration.', 'transcriptome', 'algoritmit', 'bioinformatiikka', 'dna-metylaatio', 'farmakogenetiikka', 'farmakologia', 'geeniekspression profiili', 'geenikopioiden määrä', 'hoidollinen käyttö', 'järjestelmien integraatio', 'kasvaimet', 'lääkehoito', 'neoplastinen geeniekspression säätely', 'perimän epästabiilius', 'perinnöllisyystiede', 'simulointi', 'solunsalpaajat', 'tietokoneohjelmat', 'tilastotiede', 'transkriptomi', 'yksilökohtainen lääketiede', 'body composition', 'bone mineral content', 'discordant monozygotic twin pair design', 'dna methylation', 'epigenetic regulation', 'hormone replacement therapy', 'hrt', 'menopause', 'skeletal muscle composition', 'biotekniikka', 'eläinekologia', 'evoluutio', 'hiirimakit', 'kädelliset', 'lajit', 'loiset', 'pitkittäistutkimus', 'sukkulamadot', 'suolinkaiset', 'tunnistaminen', 'madagaskar', '18s gene', 'helmints', 'infracommunity analysis', 'longitudinal study', 'metabarcoding', 'microcebus rufus', 'mouse lemurs', 'nematodes', 'parasitology', 'phylogenetic placement', 'rrna marker genes', 'ruskohiirimaki', 'alzheimer disease', 'gene expression.', 'transcriptome.', 'genetic variation.', 'multifactorial inheritance.', 'risk factors.', 'genes.', 'genetic loci.', 'alleles.', 'biological markers.', 'cerebrospinal fluid.', 'inflammation.', 'brain.', 'neuropeptive agents.', 'polymorphism, single nucleotide.', 'alzheimerin tauti', 'geeniekspressio', 'geneettinen muuntelu', 'periytyvyys', 'riskitekijät', 'markkerit', 'aivo-selkäydinneste', 'tulehdus', 'aivot', 'aineenvaihdunta', 'hevonen', 'insuliini', 'kotieläimet', 'kotieläintalous', 'laidunruokinta', 'lehmät', 'rehut', 'ruokintakokeet', 'tammat', 'ummessaolokausi', 'energiayliruokinta', 'gluconeogenesis', 'insulin resistance', 'insulin sensitivity', 'lipogenesis', 'prepartal energy', 'trasition dary cow', 'alternative splicing.', 'gene expression regulation.', 'obesity.', 'overweight.', 'weight loss.', 'adipose tissue.', 'liver.', 'transcription factor 7-like 2 protein.', 'receptor, insulin.', 'rna-binding proteins.', 'insulin.', 'insulin resistance.', 'diabetes mellitus, type 2.', 'glucose', 'fatty acids', 'lihavuus', 'ylipaino', 'rasvakudokset', 'maksa', 'insuliiniresistenssi', 'aikuistyypin diabetes', 'glukoosi', 'rasvahapot', 'human genetics', 'patents (international law)', 'right to health.', 'stem cells', 'patentit', 'biotieteet', 'kantasolut', 'endosytoosi', 'geenitekniikka', 'geeniterapia', 'kujettimet', 'testaus', 'cell differentation', 'endocytic pathway', 'endocytosis', ...

# %%
result = get_and_beautify_data_from_api(lookfor="vietnam", year="2015")
if result['records'][0] != 0:
    orgs_count = count_orgs(result['records'])#for bubble chart 
    subjects_count = count_subjects(result['records'])
    cooccurence_with_keys = count_subjects_presented_together_one_publishcation(result['records'], subjects_count)  
    cooc_matrix = cooccurence_matrix(cooccurence_with_keys)#For heatmap chart
    print("Organizations: {}\nRelated subjects: {}".format(orgs_count, list(subjects_count.keys())))
else: 
    print("No result!!!!!")
# Out:
# Organizations: {'Jyväskylän yliopisto': 9, 'Savonia-ammattikorkeakoulu': 3, 'Lahden ammattikorkeakoulu': 6, 'Tampereen ammattikorkeakoulu': 1, 'Tritonia': 2, 'Maanpuolustuskorkeakoulu': 7, 'Kansalliskirjasto': 17, 'Helmet-kirjastot': 14, 'Helka-kirjastot': 12, 'Oulun ammattikorkeakoulun kirjasto': 1, 'Svenska handelshögskolan': 1, 'Keski-kirjastot': 2, 'Lastu-kirjastot': 3, 'Eduskunnan kirjasto': 4, 'PIKI-kirjastot': 1, 'Vaski-kirjastot': 1, 'Eepos-kirjastot': 5, 'Kyyti-kirjastot': 1, 'Taideyliopisto': 1, 'OUTI-kirjastot': 1, 'Rutakko-kirjastot': 1, 'Humanistinen ammattikorkeakoulu': 2, 'Blanka-kirjastot': 1, 'Laurea-kirjasto': 1, 'Vaara-kirjastot': 1, 'Diakonia-ammattikorkeakoulun kirjasto': 1, 'Itä-Suomen yliopisto': 1}
# Related subjects: ['youth', 'social science / general', 'vietnam.', 'markkinointi', 'kampanjat', 'sosiaalinen media', 'vietnam', 'liiketoimintasuunnitelmat', 'ravintolat', 'perustaminen', 'hyönteiset', 'ruoat', 'suunnitelmat', 'kauneudenhoito', 'kuluttajakäyttäytyminen', 'kuluttajatutkimus', 'markkina-alueet', 'markkinatutkimus', 'startup-yritykset', 'uusi talous', 'jakamistalous', 'verkkopalvelut', 'haasteet', 'kyselytutkimus', 'luomuruoka', 'luomutuotteet', 'markkinat', 'asiakkaat', 'asenteet', 'kulutus', 'suomi', 'tietojärjestelmät', 'integrointi', 'joukkoliikenne', 'kaupunkiliikenne', 'linja-autoliikenne', 'metropolialueet', 'banks', 'banking', 'credit risks', 'pankit', 'pankkiala', 'luotot', 'riskit', 'kiinteistönkauppa', 'asuntokauppa', 'ostokäyttäytyminen', 'asuntomarkkinat', 'fastighetsköp', 'bostadsköp', 'köpbeteende', 'bostadsmarknaden', 'lentoliikenne', 'lentomatkailu', 'lentoyhtiöt', 'strategia', 'benchmarking', 'kansainvälinen liikenne', 'hävittäjätorjunta', 'voimankäytön säädökset', 'f-105', 'f-4', 'ilmatorjunta', 'sotahistoria', 'häirintä', 'liikeideat', 'pesulat', 'kahvilat', 'vapaa-aikatilat', 'yhteistilat', 'itsepalvelu', 'opiskelijat', 'vietnamin sota', 'elokuvat', 'sotaelokuvat', 'populaarikulttuuri', 'los angeles', 'yhdysvallat', '1970-luku', 'overdrive', 'sotilaat', 'kenraalit', 'vakoilijat', 'vietnamilaiset', 'kommunistit', 'armeijat', 'ali, muhammad.', '1960-luku', 'liikuntasosiologia', 'nyrkkeily', 'nyrkkeilijät', 'urheilu', 'politiikka', 'kansalaisoikeusliikkeet', 'viihdeteollisuus', 'demokratia', 'dialogisuus', 'kansalaisjärjestöt', 'kehitys', 'kehitystutkimus', 'kehitysyhteistyö', 'kielenkäyttö', 'naisen asema', 'osallistuminen', 'paikallisyhteisöt', 'semantiikka', 'sosiaalinen sukupuoli', 'sosiolingvistiikka', 'bakhtinian reading', 'democracy promotion', 'development pactice', 'development thinking', 'dialogical relationship', 'gender', 'gendered norms', 'grassroots democracy', 'heteroglossia', 'language in development', 'meaning construction', 'monologism', 'ngos in development', 'market research', 'marketing', 'markkinointitutkimus', 'mobiilipelit', 'pelit', 'langaton tekniikka', 'teknologia', 'mobilspel', 'spel', 'trådlös teknik', 'teknologi', 'games', 'mobile technology', 'technology', 'gambling.', 'mobile games.', 'technology acceptance model (tam)', 'unified theory of acceptance and use of technology (utaut)', 'keskustelunanalyysi', 'sukupuoliroolit', 'verkkokeskustelu', 'diskursanalys', 'könsroller', 'nätdiskussion', 'iso-britannia', 'storbritannien', 'kehittyneet maat', 'kehittäminen', 'kehitysmaat', 'korkea-asteen koulutus', 'korkeakoulut', 'projektit', 'yhteistyö', 'yliopistot', 'etelä-sudan', 'kenia', 'uganda', 'kansanmusiikki', 'perinnemusiikki', 'kansanlaulut', 'kaakkois-aasia', 'household employees', 'sex role', 'socialism', 'sosialismi', 'yhteiskunta', 'matkaoppaat', 'basset, gene,', 'vietnam war (1961-1975)', 'vietnam war, 1961-1975', 'art', 'history', 'history / military / vietnam war', 'soldiers', 'communists', 'sodat', 'sotatoimet', 'sotataito', 'aseet', 'herr, michael.', 'sotakirjeenvaihtajat', 'toimittajat', 'vietnamin kieli', 'national security.', 'history / modern / 20th century.', 'sotilaspolitiikka', 'united states.', 'musiikki', 'aiheet', 'american fiction', 'kirjallisuus', 'pojat', 'kylät', 'partisaanit', 'pakolaiset ', 'saigon ', 'kazakstan ', 'almaty ', 'hmong (asian people)', 'ethnology', 'borderlands', 'social science', 'borderlands.', 'ethnology.', 'anthropogeografie', 'grenzgebiet', 'ethnizität', 'ackerbau', 'nutztierzucht', 'handel', 'wasserbüffel', 'cashcrops', 'kardamomanbau', 'alkoholproduktion', 'weberei', 'miao', 'china', 'yunnan', 'catholic teenagers', 'students', 'drama', 'catholic teenagers.', 'protest movements.', 'students.', 'drama / australian & oceanian', 'australian drama.', 'drama.', 'ilkeys', 'vanhukset', 'sotaveteraanit', 'naapurit', 'lapsenvahdit', 'rationaalisuus', 'päätöksenteko', 'psykologia', 'sex-oriented businesses', 'business & economics', ...
